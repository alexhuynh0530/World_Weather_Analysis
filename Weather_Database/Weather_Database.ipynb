# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 745

# %%
# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# Import the datetime module from the datetime library.
from datetime import datetime

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        # Parse weather description.
        city_desc = city_weather["weather"][0]["description"]
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": city_desc})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | cherskiy
# Processing Record 2 of Set 1 | saint george
# Processing Record 3 of Set 1 | hobart
# Processing Record 4 of Set 1 | vaini
# Processing Record 5 of Set 1 | ushuaia
# Processing Record 6 of Set 1 | mogadishu
# Processing Record 7 of Set 1 | albany
# Processing Record 8 of Set 1 | mount isa
# Processing Record 9 of Set 1 | vila velha
# Processing Record 10 of Set 1 | cape town
# Processing Record 11 of Set 1 | hasaki
# Processing Record 12 of Set 1 | saint-denis
# Processing Record 13 of Set 1 | marmande
# Processing Record 14 of Set 1 | punta arenas
# Processing Record 15 of Set 1 | yerofey pavlovich
# Processing Record 16 of Set 1 | skaerbaek
# Processing Record 17 of Set 1 | verkhoyansk
# Processing Record 18 of Set 1 | barentsburg
# City not found. Skipping...
# Processing Record 19 of Set 1 | atuona
# Processing Record 20 of Set 1 | kingsport
# Processing Record 21 of Set 1 | faanui
# Processing Record 22 of Set 1 | carlyle
# Processing Record 23 of Set 1 | hithadhoo
# Processing Record 24 of Set 1 | tuktoyaktuk
# Processing Record 25 of Set 1 | busselton
# Processing Record 26 of Set 1 | codrington
# Processing Record 27 of Set 1 | san patricio
# Processing Record 28 of Set 1 | dikson
# Processing Record 29 of Set 1 | kita
# Processing Record 30 of Set 1 | chokurdakh
# Processing Record 31 of Set 1 | andilamena
# Processing Record 32 of Set 1 | port macquarie
# Processing Record 33 of Set 1 | bluff
# Processing Record 34 of Set 1 | hermanus
# Processing Record 35 of Set 1 | ilulissat
# Processing Record 36 of Set 1 | poum
# Processing Record 37 of Set 1 | thompson
# Processing Record 38 of Set 1 | upernavik
# Processing Record 39 of Set 1 | sentyabrskiy
# City not found. Skipping...
# Processing Record 40 of Set 1 | miri
# Processing Record 41 of Set 1 | narsaq
# Processing Record 42 of Set 1 | lakes entrance
# Processing Record 43 of Set 1 | grand river south east
# City not found. Skipping...
# Processing Record 44 of Set 1 | reshetylivka
# Processing Record 45 of Set 1 | khatanga
# Processing Record 46 of Set 1 | san
# Processing Record 47 of Set 1 | flinders
# Processing Record 48 of Set 1 | saskylakh
# Processing Record 49 of Set 1 | pevek
# Processing Record 50 of Set 1 | guerrero negro
# Processing Record 1 of Set 2 | makakilo city
# Processing Record 2 of Set 2 | bonavista
# Processing Record 3 of Set 2 | souillac
# Processing Record 4 of Set 2 | saint-philippe
# Processing Record 5 of Set 2 | qaanaaq
# Processing Record 6 of Set 2 | cidreira
# Processing Record 7 of Set 2 | burica
# City not found. Skipping...
# Processing Record 8 of Set 2 | port elizabeth
# Processing Record 9 of Set 2 | belle fourche
# Processing Record 10 of Set 2 | atar
# Processing Record 11 of Set 2 | clovis
# Processing Record 12 of Set 2 | jamestown
# Processing Record 13 of Set 2 | sola
# Processing Record 14 of Set 2 | coquimbo
# Processing Record 15 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 16 of Set 2 | kaitangata
# Processing Record 17 of Set 2 | salalah
# Processing Record 18 of Set 2 | bilibino
# Processing Record 19 of Set 2 | hilo
# Processing Record 20 of Set 2 | rikitea
# Processing Record 21 of Set 2 | la ronge
# Processing Record 22 of Set 2 | tasiilaq
# Processing Record 23 of Set 2 | klaksvik
# Processing Record 24 of Set 2 | pisco
# Processing Record 25 of Set 2 | kapaa
# Processing Record 26 of Set 2 | naze
# Processing Record 27 of Set 2 | belushya guba
# City not found. Skipping...
# Processing Record 28 of Set 2 | fort nelson
# Processing Record 29 of Set 2 | chuy
# Processing Record 30 of Set 2 | kodiak
# Processing Record 31 of Set 2 | contamana
# Processing Record 32 of Set 2 | culebra
# Processing Record 33 of Set 2 | verkh-usugli
# Processing Record 34 of Set 2 | bam
# Processing Record 35 of Set 2 | barrow
# Processing Record 36 of Set 2 | salihorsk
# Processing Record 37 of Set 2 | caravelas
# Processing Record 38 of Set 2 | menongue
# Processing Record 39 of Set 2 | carnarvon
# Processing Record 40 of Set 2 | hamilton
# Processing Record 41 of Set 2 | ozgon
# City not found. Skipping...
# Processing Record 42 of Set 2 | sao lourenco do oeste
# Processing Record 43 of Set 2 | provideniya
# Processing Record 44 of Set 2 | nizhneyansk
# City not found. Skipping...
# Processing Record 45 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 46 of Set 2 | marcona
# City not found. Skipping...
# Processing Record 47 of Set 2 | mataura
# Processing Record 48 of Set 2 | bambous virieux
# Processing Record 49 of Set 2 | lagoa
# Processing Record 50 of Set 2 | castro
# Processing Record 1 of Set 3 | east london
# Processing Record 2 of Set 3 | port lincoln
# Processing Record 3 of Set 3 | naantali
# Processing Record 4 of Set 3 | georgetown
# Processing Record 5 of Set 3 | new norfolk
# Processing Record 6 of Set 3 | roma
# Processing Record 7 of Set 3 | santana do matos
# Processing Record 8 of Set 3 | avarua
# Processing Record 9 of Set 3 | kasongo
# Processing Record 10 of Set 3 | ponta do sol
# Processing Record 11 of Set 3 | lebu
# Processing Record 12 of Set 3 | purpe
# Processing Record 13 of Set 3 | beyneu
# Processing Record 14 of Set 3 | tiksi
# Processing Record 15 of Set 3 | whitehorse
# Processing Record 16 of Set 3 | barcelos
# Processing Record 17 of Set 3 | olinda
# Processing Record 18 of Set 3 | havoysund
# Processing Record 19 of Set 3 | ribeira grande
# Processing Record 20 of Set 3 | vawkavysk
# Processing Record 21 of Set 3 | bowen
# Processing Record 22 of Set 3 | coahuayana
# Processing Record 23 of Set 3 | lata
# Processing Record 24 of Set 3 | saldanha
# Processing Record 25 of Set 3 | tsihombe
# City not found. Skipping...
# Processing Record 26 of Set 3 | okato
# Processing Record 27 of Set 3 | fevik
# Processing Record 28 of Set 3 | aflu
# City not found. Skipping...
# Processing Record 29 of Set 3 | suluq
# Processing Record 30 of Set 3 | port hedland
# Processing Record 31 of Set 3 | mar del plata
# Processing Record 32 of Set 3 | sobolevo
# Processing Record 33 of Set 3 | warqla
# City not found. Skipping...
# Processing Record 34 of Set 3 | torbay
# Processing Record 35 of Set 3 | cabo san lucas
# Processing Record 36 of Set 3 | road town
# Processing Record 37 of Set 3 | portree
# Processing Record 38 of Set 3 | pahrump
# Processing Record 39 of Set 3 | port alfred
# Processing Record 40 of Set 3 | abu zabad
# Processing Record 41 of Set 3 | louisbourg
# City not found. Skipping...
# Processing Record 42 of Set 3 | adrar
# Processing Record 43 of Set 3 | bredasdorp
# Processing Record 44 of Set 3 | martil
# Processing Record 45 of Set 3 | ucluelet
# Processing Record 46 of Set 3 | arraial do cabo
# Processing Record 47 of Set 3 | namibe
# Processing Record 48 of Set 3 | aklavik
# Processing Record 49 of Set 3 | ancud
# Processing Record 50 of Set 3 | romitan
# Processing Record 1 of Set 4 | tezu
# Processing Record 2 of Set 4 | alotau
# City not found. Skipping...
# Processing Record 3 of Set 4 | nanortalik
# Processing Record 4 of Set 4 | esperance
# Processing Record 5 of Set 4 | nuuk
# Processing Record 6 of Set 4 | bathsheba
# Processing Record 7 of Set 4 | sangin
# Processing Record 8 of Set 4 | kahului
# Processing Record 9 of Set 4 | biak
# Processing Record 10 of Set 4 | ilo
# Processing Record 11 of Set 4 | viedma
# Processing Record 12 of Set 4 | dehloran
# Processing Record 13 of Set 4 | kemijarvi
# Processing Record 14 of Set 4 | attawapiskat
# City not found. Skipping...
# Processing Record 15 of Set 4 | aksarka
# Processing Record 16 of Set 4 | namatanai
# Processing Record 17 of Set 4 | butembo
# Processing Record 18 of Set 4 | khandyga
# Processing Record 19 of Set 4 | san ramon
# Processing Record 20 of Set 4 | dunedin
# Processing Record 21 of Set 4 | bar harbor
# Processing Record 22 of Set 4 | neiafu
# Processing Record 23 of Set 4 | shenjiamen
# Processing Record 24 of Set 4 | longyearbyen
# Processing Record 25 of Set 4 | butaritari
# Processing Record 26 of Set 4 | dauphin
# Processing Record 27 of Set 4 | port-gentil
# Processing Record 28 of Set 4 | kulhudhuffushi
# Processing Record 29 of Set 4 | kieta
# Processing Record 30 of Set 4 | kushima
# Processing Record 31 of Set 4 | victoria
# Processing Record 32 of Set 4 | sekoma
# Processing Record 33 of Set 4 | luderitz
# Processing Record 34 of Set 4 | lovozero
# Processing Record 35 of Set 4 | muros
# Processing Record 36 of Set 4 | avera
# Processing Record 37 of Set 4 | griffith
# Processing Record 38 of Set 4 | fortuna
# Processing Record 39 of Set 4 | kavieng
# Processing Record 40 of Set 4 | anar darreh
# City not found. Skipping...
# Processing Record 41 of Set 4 | dien bien
# City not found. Skipping...
# Processing Record 42 of Set 4 | hunza
# City not found. Skipping...
# Processing Record 43 of Set 4 | acaponeta
# Processing Record 44 of Set 4 | mahibadhoo
# Processing Record 45 of Set 4 | pozo colorado
# Processing Record 46 of Set 4 | sitka
# Processing Record 47 of Set 4 | bethel
# Processing Record 48 of Set 4 | hualmay
# Processing Record 49 of Set 4 | malwan
# City not found. Skipping...
# Processing Record 50 of Set 4 | norman wells
# Processing Record 1 of Set 5 | arvika
# Processing Record 2 of Set 5 | payo
# Processing Record 3 of Set 5 | lompoc
# Processing Record 4 of Set 5 | saint-pierre
# Processing Record 5 of Set 5 | manakara
# Processing Record 6 of Set 5 | perth
# Processing Record 7 of Set 5 | bandarbeyla
# Processing Record 8 of Set 5 | birjand
# Processing Record 9 of Set 5 | dunn
# Processing Record 10 of Set 5 | puerto ayora
# Processing Record 11 of Set 5 | vestmannaeyjar
# Processing Record 12 of Set 5 | harper
# Processing Record 13 of Set 5 | yellowknife
# Processing Record 14 of Set 5 | rorvik
# Processing Record 15 of Set 5 | bengkulu
# Processing Record 16 of Set 5 | mahebourg
# Processing Record 17 of Set 5 | inta
# Processing Record 18 of Set 5 | pangody
# Processing Record 19 of Set 5 | neosho
# Processing Record 20 of Set 5 | barra patuca
# Processing Record 21 of Set 5 | anqing
# Processing Record 22 of Set 5 | mwinilunga
# Processing Record 23 of Set 5 | burpengary
# Processing Record 24 of Set 5 | kruisfontein
# Processing Record 25 of Set 5 | kijang
# Processing Record 26 of Set 5 | noumea
# Processing Record 27 of Set 5 | jinchang
# Processing Record 28 of Set 5 | umzimvubu
# City not found. Skipping...
# Processing Record 29 of Set 5 | palabuhanratu
# City not found. Skipping...
# Processing Record 30 of Set 5 | beringovskiy
# Processing Record 31 of Set 5 | koslan
# Processing Record 32 of Set 5 | wadi musa
# Processing Record 33 of Set 5 | iqaluit
# Processing Record 34 of Set 5 | vila
# Processing Record 35 of Set 5 | ulladulla
# Processing Record 36 of Set 5 | nikolskoye
# Processing Record 37 of Set 5 | riyadh
# Processing Record 38 of Set 5 | punta alta
# Processing Record 39 of Set 5 | khuzhir
# Processing Record 40 of Set 5 | nome
# Processing Record 41 of Set 5 | gizo
# Processing Record 42 of Set 5 | harer
# Processing Record 43 of Set 5 | nemuro
# Processing Record 44 of Set 5 | poshekhonye
# Processing Record 45 of Set 5 | chengzihe
# Processing Record 46 of Set 5 | lorengau
# Processing Record 47 of Set 5 | katsuura
# Processing Record 48 of Set 5 | sehnde
# Processing Record 49 of Set 5 | zilair
# Processing Record 50 of Set 5 | seoul
# Processing Record 1 of Set 6 | lolua
# City not found. Skipping...
# Processing Record 2 of Set 6 | bolshoy uluy
# City not found. Skipping...
# Processing Record 3 of Set 6 | lanigan
# Processing Record 4 of Set 6 | abalak
# Processing Record 5 of Set 6 | cayenne
# Processing Record 6 of Set 6 | sodertalje
# City not found. Skipping...
# Processing Record 7 of Set 6 | talnakh
# Processing Record 8 of Set 6 | kudahuvadhoo
# Processing Record 9 of Set 6 | vagay
# Processing Record 10 of Set 6 | korem
# Processing Record 11 of Set 6 | gazli
# Processing Record 12 of Set 6 | abdanan
# Processing Record 13 of Set 6 | udachnyy
# Processing Record 14 of Set 6 | nioki
# Processing Record 15 of Set 6 | siva
# Processing Record 16 of Set 6 | lavrentiya
# Processing Record 17 of Set 6 | kuna
# Processing Record 18 of Set 6 | tirano
# Processing Record 19 of Set 6 | cartagena
# Processing Record 20 of Set 6 | chau doc
# Processing Record 21 of Set 6 | antofagasta
# Processing Record 22 of Set 6 | vaitupu
# City not found. Skipping...
# Processing Record 23 of Set 6 | kumla
# Processing Record 24 of Set 6 | richards bay
# Processing Record 25 of Set 6 | fairbanks
# Processing Record 26 of Set 6 | hovd
# Processing Record 27 of Set 6 | padang
# Processing Record 28 of Set 6 | okhotsk
# Processing Record 29 of Set 6 | oranjestad
# Processing Record 30 of Set 6 | beaverlodge
# Processing Record 31 of Set 6 | marienburg
# Processing Record 32 of Set 6 | saleaula
# City not found. Skipping...
# Processing Record 33 of Set 6 | bubaque
# Processing Record 34 of Set 6 | hami
# Processing Record 35 of Set 6 | denpasar
# Processing Record 36 of Set 6 | gravdal
# Processing Record 37 of Set 6 | abapo
# Processing Record 38 of Set 6 | topeka
# Processing Record 39 of Set 6 | bodaybo
# Processing Record 40 of Set 6 | berlevag
# Processing Record 41 of Set 6 | marystown
# Processing Record 42 of Set 6 | kholm-zhirkovskiy
# Processing Record 43 of Set 6 | alghero
# Processing Record 44 of Set 6 | sambava
# Processing Record 45 of Set 6 | paamiut
# Processing Record 46 of Set 6 | itoigawa
# Processing Record 47 of Set 6 | tessalit
# Processing Record 48 of Set 6 | amderma
# City not found. Skipping...
# Processing Record 49 of Set 6 | vraca
# Processing Record 50 of Set 6 | port blair
# Processing Record 1 of Set 7 | khudumelapye
# Processing Record 2 of Set 7 | huangchuan
# Processing Record 3 of Set 7 | nishihara
# Processing Record 4 of Set 7 | nizhnevartovsk
# Processing Record 5 of Set 7 | margate
# Processing Record 6 of Set 7 | severo-kurilsk
# Processing Record 7 of Set 7 | sapao
# City not found. Skipping...
# Processing Record 8 of Set 7 | karatau
# Processing Record 9 of Set 7 | elizabeth city
# Processing Record 10 of Set 7 | taksimo
# Processing Record 11 of Set 7 | tlacolula
# Processing Record 12 of Set 7 | esso
# Processing Record 13 of Set 7 | maceio
# Processing Record 14 of Set 7 | palana
# Processing Record 15 of Set 7 | pinczow
# Processing Record 16 of Set 7 | ibipeba
# Processing Record 17 of Set 7 | giyani
# Processing Record 18 of Set 7 | pimentel
# Processing Record 19 of Set 7 | strelka
# Processing Record 20 of Set 7 | solnechnyy
# Processing Record 21 of Set 7 | maryborough
# Processing Record 22 of Set 7 | igarapava
# Processing Record 23 of Set 7 | oussouye
# Processing Record 24 of Set 7 | tecpan
# Processing Record 25 of Set 7 | saurimo
# Processing Record 26 of Set 7 | komsomolskiy
# Processing Record 27 of Set 7 | alice springs
# Processing Record 28 of Set 7 | airai
# Processing Record 29 of Set 7 | tadine
# Processing Record 30 of Set 7 | kyaikkami
# Processing Record 31 of Set 7 | arman
# Processing Record 32 of Set 7 | la libertad
# Processing Record 33 of Set 7 | clarence town
# Processing Record 34 of Set 7 | havelock
# Processing Record 35 of Set 7 | lanivtsi
# Processing Record 36 of Set 7 | fevralsk
# City not found. Skipping...
# Processing Record 37 of Set 7 | chanderi
# Processing Record 38 of Set 7 | taki
# Processing Record 39 of Set 7 | kichera
# Processing Record 40 of Set 7 | yabelo
# Processing Record 41 of Set 7 | san policarpo
# Processing Record 42 of Set 7 | karaul
# City not found. Skipping...
# Processing Record 43 of Set 7 | los llanos de aridane
# Processing Record 44 of Set 7 | mocuba
# Processing Record 45 of Set 7 | malibu
# Processing Record 46 of Set 7 | geraldton
# Processing Record 47 of Set 7 | kracheh
# City not found. Skipping...
# Processing Record 48 of Set 7 | aykhal
# Processing Record 49 of Set 7 | kimbe
# Processing Record 50 of Set 7 | traverse city
# Processing Record 1 of Set 8 | rovaniemi
# Processing Record 2 of Set 8 | oktyabrskiy
# Processing Record 3 of Set 8 | tumannyy
# City not found. Skipping...
# Processing Record 4 of Set 8 | mariinsk
# Processing Record 5 of Set 8 | dingle
# Processing Record 6 of Set 8 | ostrovnoy
# Processing Record 7 of Set 8 | palmer
# Processing Record 8 of Set 8 | chimbote
# Processing Record 9 of Set 8 | dargaville
# Processing Record 10 of Set 8 | abu dhabi
# Processing Record 11 of Set 8 | nurota
# Processing Record 12 of Set 8 | amlagora
# Processing Record 13 of Set 8 | inderborskiy
# City not found. Skipping...
# Processing Record 14 of Set 8 | moussoro
# Processing Record 15 of Set 8 | rio grande
# Processing Record 16 of Set 8 | maghama
# City not found. Skipping...
# Processing Record 17 of Set 8 | preston
# Processing Record 18 of Set 8 | rostaq
# City not found. Skipping...
# Processing Record 19 of Set 8 | mys shmidta
# City not found. Skipping...
# Processing Record 20 of Set 8 | gamba
# Processing Record 21 of Set 8 | warwick
# Processing Record 22 of Set 8 | castrillon
# Processing Record 23 of Set 8 | villazon
# Processing Record 24 of Set 8 | libreville
# Processing Record 25 of Set 8 | akcakoca
# Processing Record 26 of Set 8 | oktyabrskoye
# Processing Record 27 of Set 8 | bouna
# Processing Record 28 of Set 8 | soe
# Processing Record 29 of Set 8 | baltatesti
# Processing Record 30 of Set 8 | xining
# Processing Record 31 of Set 8 | sucua
# Processing Record 32 of Set 8 | constitucion
# Processing Record 33 of Set 8 | qostanay
# Processing Record 34 of Set 8 | raipur
# Processing Record 35 of Set 8 | yatou
# Processing Record 36 of Set 8 | kyzyl-suu
# Processing Record 37 of Set 8 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 38 of Set 8 | labrea
# Processing Record 39 of Set 8 | rio brilhante
# Processing Record 40 of Set 8 | bolungarvik
# City not found. Skipping...
# Processing Record 41 of Set 8 | pemangkat
# Processing Record 42 of Set 8 | laurel
# Processing Record 43 of Set 8 | kollam
# Processing Record 44 of Set 8 | broome
# Processing Record 45 of Set 8 | batagay-alyta
# Processing Record 46 of Set 8 | barkhan
# Processing Record 47 of Set 8 | glendive
# Processing Record 48 of Set 8 | straumen
# Processing Record 49 of Set 8 | montrose
# Processing Record 50 of Set 8 | moffat
# Processing Record 1 of Set 9 | san cristobal
# Processing Record 2 of Set 9 | stepnyak
# Processing Record 3 of Set 9 | taicheng
# Processing Record 4 of Set 9 | zaraza
# Processing Record 5 of Set 9 | zhigansk
# Processing Record 6 of Set 9 | tura
# Processing Record 7 of Set 9 | roebourne
# Processing Record 8 of Set 9 | gardan diwal
# City not found. Skipping...
# Processing Record 9 of Set 9 | lishui
# Processing Record 10 of Set 9 | sao filipe
# Processing Record 11 of Set 9 | vila franca do campo
# Processing Record 12 of Set 9 | sao miguel do araguaia
# Processing Record 13 of Set 9 | chimoio
# Processing Record 14 of Set 9 | vardo
# Processing Record 15 of Set 9 | leningradskiy
# Processing Record 16 of Set 9 | shinshiro
# Processing Record 17 of Set 9 | wanning
# Processing Record 18 of Set 9 | cao bang
# Processing Record 19 of Set 9 | kulu
# Processing Record 20 of Set 9 | roald
# Processing Record 21 of Set 9 | ekibastuz
# Processing Record 22 of Set 9 | tuatapere
# Processing Record 23 of Set 9 | ketchikan
# Processing Record 24 of Set 9 | hambantota
# Processing Record 25 of Set 9 | san quintin
# Processing Record 26 of Set 9 | paine
# Processing Record 27 of Set 9 | carutapera
# Processing Record 28 of Set 9 | tazovskiy
# Processing Record 29 of Set 9 | kuruman
# Processing Record 30 of Set 9 | kalmar
# Processing Record 31 of Set 9 | redcar
# Processing Record 32 of Set 9 | hecun
# Processing Record 33 of Set 9 | haines junction
# Processing Record 34 of Set 9 | taoudenni
# Processing Record 35 of Set 9 | acapulco
# Processing Record 36 of Set 9 | sosnovo
# Processing Record 37 of Set 9 | maningrida
# Processing Record 38 of Set 9 | morlenbach
# Processing Record 39 of Set 9 | kavaratti
# Processing Record 40 of Set 9 | strezhevoy
# Processing Record 41 of Set 9 | sibu
# Processing Record 42 of Set 9 | jiangyan
# Processing Record 43 of Set 9 | atikokan
# Processing Record 44 of Set 9 | umm lajj
# Processing Record 45 of Set 9 | omsukchan
# Processing Record 46 of Set 9 | lasa
# Processing Record 47 of Set 9 | puerto madryn
# Processing Record 48 of Set 9 | dangriga
# Processing Record 49 of Set 9 | carlisle
# Processing Record 50 of Set 9 | aketi
# Processing Record 1 of Set 10 | homer
# Processing Record 2 of Set 10 | pacific grove
# Processing Record 3 of Set 10 | guatire
# Processing Record 4 of Set 10 | praia
# Processing Record 5 of Set 10 | yumen
# Processing Record 6 of Set 10 | tayturka
# Processing Record 7 of Set 10 | nioro
# Processing Record 8 of Set 10 | coihaique
# Processing Record 9 of Set 10 | weinan
# Processing Record 10 of Set 10 | college
# Processing Record 11 of Set 10 | acari
# Processing Record 12 of Set 10 | brigantine
# Processing Record 13 of Set 10 | brae
# Processing Record 14 of Set 10 | haikou
# Processing Record 15 of Set 10 | billings
# Processing Record 16 of Set 10 | tahoua
# Processing Record 17 of Set 10 | puerto el triunfo
# Processing Record 18 of Set 10 | artyk
# City not found. Skipping...
# Processing Record 19 of Set 10 | teahupoo
# Processing Record 20 of Set 10 | tautira
# Processing Record 21 of Set 10 | mecca
# Processing Record 22 of Set 10 | nizwa
# Processing Record 23 of Set 10 | sao joao da barra
# Processing Record 24 of Set 10 | inhambane
# Processing Record 25 of Set 10 | vieksniai
# Processing Record 26 of Set 10 | anadyr
# Processing Record 27 of Set 10 | port-cartier
# Processing Record 28 of Set 10 | kiunga
# Processing Record 29 of Set 10 | toktogul
# Processing Record 30 of Set 10 | la rioja
# Processing Record 31 of Set 10 | mackay
# Processing Record 32 of Set 10 | novoomskiy
# Processing Record 33 of Set 10 | henties bay
# Processing Record 34 of Set 10 | waipawa
# Processing Record 35 of Set 10 | kamenka
# Processing Record 36 of Set 10 | sarrebourg
# Processing Record 37 of Set 10 | mulchen
# Processing Record 38 of Set 10 | ahipara
# Processing Record 39 of Set 10 | gushikawa
# Processing Record 40 of Set 10 | shitanjing
# Processing Record 41 of Set 10 | vanimo
# Processing Record 42 of Set 10 | novotroitsk
# Processing Record 43 of Set 10 | kerman
# Processing Record 44 of Set 10 | labe
# Processing Record 45 of Set 10 | quixada
# Processing Record 46 of Set 10 | wonthaggi
# Processing Record 47 of Set 10 | tlahualilo
# City not found. Skipping...
# Processing Record 48 of Set 10 | husavik
# Processing Record 49 of Set 10 | dusti
# Processing Record 50 of Set 10 | chumikan
# Processing Record 1 of Set 11 | miedzychod
# Processing Record 2 of Set 11 | wewak
# Processing Record 3 of Set 11 | port hardy
# Processing Record 4 of Set 11 | rio gallegos
# Processing Record 5 of Set 11 | saint stephen
# Processing Record 6 of Set 11 | chifeng
# Processing Record 7 of Set 11 | cheremukhovo
# Processing Record 8 of Set 11 | samarai
# Processing Record 9 of Set 11 | penha
# Processing Record 10 of Set 11 | pemagatsel
# Processing Record 11 of Set 11 | goderich
# Processing Record 12 of Set 11 | boyolangu
# Processing Record 13 of Set 11 | yate
# Processing Record 14 of Set 11 | khorixas
# Processing Record 15 of Set 11 | bud
# Processing Record 16 of Set 11 | manaure
# Processing Record 17 of Set 11 | san lawrenz
# Processing Record 18 of Set 11 | methoni
# Processing Record 19 of Set 11 | sabratah
# Processing Record 20 of Set 11 | phnum penh
# City not found. Skipping...
# Processing Record 21 of Set 11 | fram
# Processing Record 22 of Set 11 | ngunguru
# Processing Record 23 of Set 11 | metro
# Processing Record 24 of Set 11 | petropavlovsk-kamchatskiy
# Processing Record 25 of Set 11 | vilhena
# Processing Record 26 of Set 11 | gharb
# City not found. Skipping...
# Processing Record 27 of Set 11 | raton
# Processing Record 28 of Set 11 | guaruja
# Processing Record 29 of Set 11 | toba
# Processing Record 30 of Set 11 | tual
# Processing Record 31 of Set 11 | qrendi
# Processing Record 32 of Set 11 | kattivakkam
# Processing Record 33 of Set 11 | matara
# Processing Record 34 of Set 11 | vestmanna
# Processing Record 35 of Set 11 | goshen
# Processing Record 36 of Set 11 | piracicaba
# Processing Record 37 of Set 11 | gat
# Processing Record 38 of Set 11 | camalu
# Processing Record 39 of Set 11 | florida
# Processing Record 40 of Set 11 | jacqueville
# Processing Record 41 of Set 11 | biankouma
# Processing Record 42 of Set 11 | marsa matruh
# Processing Record 43 of Set 11 | beloha
# Processing Record 44 of Set 11 | samusu
# City not found. Skipping...
# Processing Record 45 of Set 11 | pucara
# Processing Record 46 of Set 11 | ust-kuyga
# Processing Record 47 of Set 11 | simi
# Processing Record 48 of Set 11 | ingham
# Processing Record 49 of Set 11 | celestun
# Processing Record 50 of Set 11 | sao felix do xingu
# Processing Record 1 of Set 12 | aljezur
# Processing Record 2 of Set 12 | nipawin
# Processing Record 3 of Set 12 | sala consilina
# Processing Record 4 of Set 12 | aloleng
# Processing Record 5 of Set 12 | bella union
# Processing Record 6 of Set 12 | moron
# Processing Record 7 of Set 12 | cortez
# Processing Record 8 of Set 12 | cockburn town
# Processing Record 9 of Set 12 | gold coast
# Processing Record 10 of Set 12 | san vicente
# Processing Record 11 of Set 12 | natitingou
# Processing Record 12 of Set 12 | samalaeulu
# City not found. Skipping...
# Processing Record 13 of Set 12 | borama
# City not found. Skipping...
# Processing Record 14 of Set 12 | labuhan
# Processing Record 15 of Set 12 | kainantu
# Processing Record 16 of Set 12 | manta
# Processing Record 17 of Set 12 | termoli
# Processing Record 18 of Set 12 | inza
# Processing Record 19 of Set 12 | berdyuzhye
# City not found. Skipping...
# Processing Record 20 of Set 12 | mergui
# City not found. Skipping...
# Processing Record 21 of Set 12 | daru
# Processing Record 22 of Set 12 | cascais
# Processing Record 23 of Set 12 | ajdabiya
# Processing Record 24 of Set 12 | oskarshamn
# Processing Record 25 of Set 12 | balsas
# Processing Record 26 of Set 12 | beyla
# Processing Record 27 of Set 12 | luzhou
# Processing Record 28 of Set 12 | hirara
# Processing Record 29 of Set 12 | effingham
# Processing Record 30 of Set 12 | luanda
# Processing Record 31 of Set 12 | hofn
# Processing Record 32 of Set 12 | kindersley
# Processing Record 33 of Set 12 | meulaboh
# Processing Record 34 of Set 12 | bereda
# Processing Record 35 of Set 12 | isangel
# Processing Record 36 of Set 12 | tripoli
# Processing Record 37 of Set 12 | yetholm
# City not found. Skipping...
# Processing Record 38 of Set 12 | ust-nera
# Processing Record 39 of Set 12 | artyom
# Processing Record 40 of Set 12 | ngama
# Processing Record 41 of Set 12 | lazaro cardenas
# Processing Record 42 of Set 12 | nyagan
# Processing Record 43 of Set 12 | belyy yar
# Processing Record 44 of Set 12 | kangaatsiaq
# Processing Record 45 of Set 12 | lakatoro
# Processing Record 46 of Set 12 | bilma
# Processing Record 47 of Set 12 | bambanglipuro
# Processing Record 48 of Set 12 | yulara
# Processing Record 49 of Set 12 | ferrenafe
# Processing Record 50 of Set 12 | sumbawa
# City not found. Skipping...
# Processing Record 1 of Set 13 | kloulklubed
# Processing Record 2 of Set 13 | lingyuan
# Processing Record 3 of Set 13 | mapiripan
# Processing Record 4 of Set 13 | padre bernardo
# Processing Record 5 of Set 13 | chitral
# Processing Record 6 of Set 13 | paungde
# Processing Record 7 of Set 13 | yirol
# City not found. Skipping...
# Processing Record 8 of Set 13 | launceston
# Processing Record 9 of Set 13 | pombas
# Processing Record 10 of Set 13 | satitoa
# City not found. Skipping...
# Processing Record 11 of Set 13 | santa vitoria do palmar
# Processing Record 12 of Set 13 | uray
# Processing Record 13 of Set 13 | myitkyina
# Processing Record 14 of Set 13 | chicama
# Processing Record 15 of Set 13 | van buren
# Processing Record 16 of Set 13 | kem
# Processing Record 17 of Set 13 | grand-santi
# Processing Record 18 of Set 13 | teknaf
# Processing Record 19 of Set 13 | derzhavinsk
# Processing Record 20 of Set 13 | putina
# Processing Record 21 of Set 13 | ondjiva
# Processing Record 22 of Set 13 | mbanza-ngungu
# Processing Record 23 of Set 13 | saint anthony
# Processing Record 24 of Set 13 | asau
# Processing Record 25 of Set 13 | mbeya
# Processing Record 26 of Set 13 | praia da vitoria
# Processing Record 27 of Set 13 | ust-kan
# Processing Record 28 of Set 13 | durango
# Processing Record 29 of Set 13 | mansa
# Processing Record 30 of Set 13 | khash
# Processing Record 31 of Set 13 | outjo
# Processing Record 32 of Set 13 | jesus del monte
# Processing Record 33 of Set 13 | bolshiye uki
# City not found. Skipping...
# Processing Record 34 of Set 13 | isa khel
# Processing Record 35 of Set 13 | takoradi
# Processing Record 36 of Set 13 | irbit
# Processing Record 37 of Set 13 | labutta
# City not found. Skipping...
# Processing Record 38 of Set 13 | valleyview
# Processing Record 39 of Set 13 | uroteppa
# City not found. Skipping...
# Processing Record 40 of Set 13 | manokwari
# Processing Record 41 of Set 13 | rincon
# Processing Record 42 of Set 13 | kalush
# Processing Record 43 of Set 13 | laguna
# Processing Record 44 of Set 13 | mwense
# Processing Record 45 of Set 13 | koungou
# Processing Record 46 of Set 13 | teguldet
# Processing Record 47 of Set 13 | manicore
# Processing Record 48 of Set 13 | derna
# Processing Record 49 of Set 13 | mayo
# Processing Record 50 of Set 13 | herat
# Processing Record 1 of Set 14 | zolotinka
# City not found. Skipping...
# Processing Record 2 of Set 14 | tanout
# Processing Record 3 of Set 14 | sale
# Processing Record 4 of Set 14 | manono
# Processing Record 5 of Set 14 | izumo
# Processing Record 6 of Set 14 | severnoye
# Processing Record 7 of Set 14 | rameshki
# Processing Record 8 of Set 14 | peterhead
# Processing Record 9 of Set 14 | zalantun
# Processing Record 10 of Set 14 | deputatskiy
# Processing Record 11 of Set 14 | novopavlovka
# Processing Record 12 of Set 14 | sabang
# Processing Record 13 of Set 14 | faya
# Processing Record 14 of Set 14 | mumford
# Processing Record 15 of Set 14 | lloydminster
# Processing Record 16 of Set 14 | nicoya
# Processing Record 17 of Set 14 | chapais
# Processing Record 18 of Set 14 | brokopondo
# Processing Record 19 of Set 14 | vung tau
# Processing Record 20 of Set 14 | yar-sale
# Processing Record 21 of Set 14 | north bend
# Processing Record 22 of Set 14 | pithoragarh
# Processing Record 23 of Set 14 | gambela
# Processing Record 24 of Set 14 | egvekinot
# Processing Record 25 of Set 14 | kandrian
# Processing Record 26 of Set 14 | awjilah
# Processing Record 27 of Set 14 | muisne
# Processing Record 28 of Set 14 | abong mbang
# Processing Record 29 of Set 14 | talara
# Processing Record 30 of Set 14 | waingapu
# Processing Record 31 of Set 14 | jaicos
# Processing Record 32 of Set 14 | touros
# Processing Record 33 of Set 14 | trincomalee
# Processing Record 34 of Set 14 | barbar
# City not found. Skipping...
# Processing Record 35 of Set 14 | santa fe
# Processing Record 36 of Set 14 | grand gaube
# Processing Record 37 of Set 14 | manoel urbano
# Processing Record 38 of Set 14 | cururupu
# Processing Record 39 of Set 14 | benjamin aceval
# Processing Record 40 of Set 14 | jardinopolis
# Processing Record 41 of Set 14 | la ciotat
# Processing Record 42 of Set 14 | kuching
# Processing Record 43 of Set 14 | palladam
# Processing Record 44 of Set 14 | yokadouma
# Processing Record 45 of Set 14 | necochea
# Processing Record 46 of Set 14 | coffs harbour
# Processing Record 47 of Set 14 | segbwema
# Processing Record 48 of Set 14 | saquena
# Processing Record 49 of Set 14 | shimoda
# Processing Record 50 of Set 14 | jieshi
# Processing Record 1 of Set 15 | naron
# Processing Record 2 of Set 15 | bargal
# City not found. Skipping...
# Processing Record 3 of Set 15 | kysyl-syr
# Processing Record 4 of Set 15 | kununurra
# Processing Record 5 of Set 15 | west wendover
# Processing Record 6 of Set 15 | shetpe
# Processing Record 7 of Set 15 | mareeba
# Processing Record 8 of Set 15 | meyungs
# City not found. Skipping...
# Processing Record 9 of Set 15 | praxedis guerrero
# Processing Record 10 of Set 15 | lahij
# Processing Record 11 of Set 15 | ibadan
# Processing Record 12 of Set 15 | turkistan
# Processing Record 13 of Set 15 | kualakapuas
# Processing Record 14 of Set 15 | umm kaddadah
# Processing Record 15 of Set 15 | lokomotivnyy
# Processing Record 16 of Set 15 | camocim
# Processing Record 17 of Set 15 | kunashak
# Processing Record 18 of Set 15 | aasiaat
# Processing Record 19 of Set 15 | maniwaki
# Processing Record 20 of Set 15 | lesnica
# Processing Record 21 of Set 15 | bronnoysund
# Processing Record 22 of Set 15 | zasheyek
# Processing Record 23 of Set 15 | karamea
# City not found. Skipping...
# Processing Record 24 of Set 15 | saint-augustin
# Processing Record 25 of Set 15 | rantepao
# Processing Record 26 of Set 15 | kropotkin
# Processing Record 27 of Set 15 | shieli
# Processing Record 28 of Set 15 | batticaloa
# Processing Record 29 of Set 15 | biltine
# Processing Record 30 of Set 15 | kouroussa
# Processing Record 31 of Set 15 | acarau
# Processing Record 32 of Set 15 | linjiang
# Processing Record 33 of Set 15 | lufilufi
# Processing Record 34 of Set 15 | mitsamiouli
# Processing Record 35 of Set 15 | zhirnovsk
# Processing Record 36 of Set 15 | hinton
# Processing Record 37 of Set 15 | chiang klang
# Processing Record 38 of Set 15 | tekkali
# Processing Record 39 of Set 15 | half moon bay
# Processing Record 40 of Set 15 | catuday
# Processing Record 41 of Set 15 | jalandhar
# Processing Record 42 of Set 15 | cockburn harbour
# City not found. Skipping...
# Processing Record 43 of Set 15 | littleton
# Processing Record 44 of Set 15 | balikpapan
# Processing Record 45 of Set 15 | kyabe
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#            City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0      Cherskiy      RU  68.7500  161.3000     20.17        96          93
# 1  Saint George      US  37.1041 -113.5841     90.19        13           1
# 2        Hobart      AU -42.8794  147.3294     61.02        85          75
# 3         Vaini      TO -21.2000 -175.2000     75.36        83          90
# 4       Ushuaia      AR -54.8000  -68.3000     38.86        70          75
# 5     Mogadishu      SO   2.0371   45.3438     78.12        84          40
# 6        Albany      US  42.6001  -73.9662     62.67        93         100
# 7     Mount Isa      AU -20.7333  139.5000     80.37        18          21
# 8    Vila Velha      BR -20.3297  -40.2925     78.75        78          40
# 9     Cape Town      ZA -33.9258   18.4232     55.11        66           2
#
#    Wind Speed      Current Description
# 0        3.02          overcast clouds
# 1        3.00                clear sky
# 2        1.99            broken clouds
# 3       13.80          overcast clouds
# 4       14.97  light intensity drizzle
# 5       13.33         scattered clouds
# 6        1.21               light rain
# 7       12.66               few clouds
# 8       16.11         scattered clouds
# 9       17.43                clear sky

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")

# %%
# !pip list
# Out:
# Package                            Version
# ---------------------------------- -------------------
# alabaster                          0.7.12
# anaconda-client                    1.7.2
# anaconda-navigator                 2.0.4
# anaconda-project                   0.9.1
# anyio                              2.2.0
# appdirs                            1.4.4
# applaunchservices                  0.2.1
# appnope                            0.1.2
# appscript                          1.1.2
# argh                               0.26.2
# argon2-cffi                        20.1.0
# asn1crypto                         1.4.0
# astroid                            2.5
# astropy                            4.2.1
# async-generator                    1.10
# atomicwrites                       1.4.0
# attrs                              20.3.0
# autopep8                           1.5.6
# Babel                              2.9.0
# backcall                           0.2.0
# backports.functools-lru-cache      1.6.4
# backports.shutil-get-terminal-size 1.0.0
# backports.tempfile                 1.0
# backports.weakref                  1.0.post1
# beautifulsoup4                     4.9.3
# bitarray                           1.9.2
# bkcharts                           0.2
# black                              19.10b0
# bleach                             3.3.0
# bokeh                              2.3.2
# boto                               2.49.0
# Bottleneck                         1.3.2
# brotlipy                           0.7.0
# certifi                            2020.12.5
# cffi                               1.14.5
# chardet                            4.0.0
# citipy                             0.0.5
# click                              7.1.2
# cloudpickle                        1.6.0
# clyent                             1.2.2
# colorama                           0.4.4
# conda                              4.10.3
# conda-build                        3.21.4
# conda-content-trust                0+unknown
# conda-package-handling             1.7.3
# conda-repo-cli                     1.0.4
# conda-token                        0.3.0
# conda-verify                       3.4.2
# contextlib2                        0.6.0.post1
# cryptography                       3.4.7
# cycler                             0.10.0
# Cython                             0.29.23
# cytoolz                            0.11.0
# dask                               2021.4.0
# decorator                          5.0.6
# defusedxml                         0.7.1
# diff-match-patch                   20200713
# distributed                        2021.4.0
# docutils                           0.17
# entrypoints                        0.3
# et-xmlfile                         1.0.1
# fastcache                          1.1.0
# filelock                           3.0.12
# flake8                             3.9.0
# Flask                              1.1.2
# fsspec                             0.9.0
# future                             0.18.2
# geojson                            2.5.0
# gevent                             21.1.2
# glob2                              0.7
# gmaps                              0.9.0
# gmpy2                              2.0.8
# greenlet                           1.0.0
# h5py                               2.10.0
# HeapDict                           1.0.1
# html5lib                           1.1
# idna                               2.10
# imageio                            2.9.0
# imagesize                          1.2.0
# importlib-metadata                 3.10.0
# iniconfig                          1.1.1
# intervaltree                       3.1.0
# ipykernel                          5.3.4
# ipython                            7.22.0
# ipython-genutils                   0.2.0
# ipywidgets                         7.6.3
# isort                              5.8.0
# itsdangerous                       1.1.0
# jdcal                              1.4.1
# jedi                               0.17.2
# Jinja2                             2.11.3
# joblib                             1.0.1
# json5                              0.9.5
# jsonschema                         3.2.0
# jupyter                            1.0.0
# jupyter-client                     6.1.12
# jupyter-console                    6.4.0
# jupyter-core                       4.7.1
# jupyter-packaging                  0.7.12
# jupyter-server                     1.4.1
# jupyterlab                         3.0.14
# jupyterlab-pygments                0.1.2
# jupyterlab-server                  2.4.0
# jupyterlab-widgets                 1.0.0
# kdtree                             0.16
# keyring                            22.3.0
# kiwisolver                         1.3.1
# lazy-object-proxy                  1.6.0
# libarchive-c                       2.9
# llvmlite                           0.36.0
# locket                             0.2.1
# lxml                               4.6.3
# MarkupSafe                         1.1.1
# matplotlib                         3.3.4
# mccabe                             0.6.1
# mistune                            0.8.4
# mkl-fft                            1.3.0
# mkl-random                         1.2.1
# mkl-service                        2.3.0
# mock                               4.0.3
# more-itertools                     8.7.0
# mpmath                             1.2.1
# msgpack                            1.0.2
# multipledispatch                   0.6.0
# mypy-extensions                    0.4.3
# navigator-updater                  0.2.1
# nbclassic                          0.2.6
# nbclient                           0.5.3
# nbconvert                          6.0.7
# nbformat                           5.1.3
# nest-asyncio                       1.5.1
# networkx                           2.5
# nltk                               3.6.1
# nose                               1.3.7
# notebook                           6.3.0
# numba                              0.53.1
# numexpr                            2.7.3
# numpy                              1.20.1
# numpydoc                           1.1.0
# olefile                            0.46
# openpyxl                           3.0.7
# packaging                          20.9
# pandas                             1.2.4
# pandocfilters                      1.4.3
# parso                              0.7.0
# partd                              1.2.0
# path                               15.1.2
# pathlib2                           2.3.5
# pathspec                           0.7.0
# patsy                              0.5.1
# pep8                               1.7.1
# pexpect                            4.8.0
# pickleshare                        0.7.5
# Pillow                             8.2.0
# pip                                21.0.1
# pkginfo                            1.7.0
# pluggy                             0.13.1
# ply                                3.11
# prometheus-client                  0.10.1
# prompt-toolkit                     3.0.17
# psutil                             5.8.0
# ptyprocess                         0.7.0
# py                                 1.10.0
# pycodestyle                        2.6.0
# pycosat                            0.6.3
# pycparser                          2.20
# pycurl                             7.43.0.6
# pydocstyle                         6.0.0
# pyerfa                             1.7.3
# pyflakes                           2.2.0
# Pygments                           2.8.1
# pylint                             2.7.4
# pyls-black                         0.4.6
# pyls-spyder                        0.3.2
# pyodbc                             4.0.0-unsupported
# pyOpenSSL                          20.0.1
# pyparsing                          2.4.7
# pyrsistent                         0.17.3
# PySocks                            1.7.1
# pytest                             6.2.3
# python-dateutil                    2.8.1
# python-jsonrpc-server              0.4.0
# python-language-server             0.36.2
# pytz                               2021.1
# PyWavelets                         1.1.1
# PyYAML                             5.4.1
# pyzmq                              20.0.0
# QDarkStyle                         2.8.1
# QtAwesome                          1.0.2
# qtconsole                          5.0.3
# QtPy                               1.9.0
# regex                              2021.4.4
# requests                           2.25.1
# rope                               0.18.0
# Rtree                              0.9.7
# ruamel-yaml-conda                  0.15.100
# scikit-image                       0.18.1
# scikit-learn                       0.24.1
# scipy                              1.6.2
# seaborn                            0.11.1
# Send2Trash                         1.5.0
# setuptools                         52.0.0.post20210125
# simplegeneric                      0.8.1
# singledispatch                     0.0.0
# six                                1.15.0
# sniffio                            1.2.0
# snowballstemmer                    2.1.0
# sortedcollections                  2.1.0
# sortedcontainers                   2.3.0
# soupsieve                          2.2.1
# Sphinx                             4.0.1
# sphinxcontrib-applehelp            1.0.2
# sphinxcontrib-devhelp              1.0.2
# sphinxcontrib-htmlhelp             1.0.3
# sphinxcontrib-jsmath               1.0.1
# sphinxcontrib-qthelp               1.0.3
# sphinxcontrib-serializinghtml      1.1.4
# sphinxcontrib-websupport           1.2.4
# spyder                             4.2.5
# spyder-kernels                     1.10.2
# SQLAlchemy                         1.4.7
# statsmodels                        0.12.2
# sympy                              1.8
# tables                             3.6.1
# tblib                              1.7.0
# terminado                          0.9.4
# testpath                           0.4.4
# textdistance                       4.2.1
# threadpoolctl                      2.1.0
# three-merge                        0.1.1
# tifffile                           2020.10.1
# toml                               0.10.2
# toolz                              0.11.1
# tornado                            6.1
# tqdm                               4.59.0
# traitlets                          5.0.5
# typed-ast                          1.4.2
# typing-extensions                  3.7.4.3
# ujson                              4.0.2
# unicodecsv                         0.14.1
# urllib3                            1.26.4
# watchdog                           1.0.2
# wcwidth                            0.2.5
# webencodings                       0.5.1
# Werkzeug                           1.0.1
# wheel                              0.36.2
# widgetsnbextension                 3.5.1
# wrapt                              1.12.1
# wurlitzer                          2.1.0
# xlrd                               2.0.1
# XlsxWriter                         1.3.8
# xlwings                            0.23.0
# xlwt                               1.3.0
# xmltodict                          0.12.0
# yapf                               0.31.0
# zict                               2.0.0
# zipp                               3.4.1
# zope.event                         4.5.0
# zope.interface                     5.3.0
